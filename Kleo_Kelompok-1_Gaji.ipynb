# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data set gaji.txt')
print(data)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.sort_values('age')
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 12318   17            Private  127366           11th              7
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status        occupation    relationship  \
# 12318        Never-married             Sales       Own-child
# ...

# %%
data.sort_values(['age', 'salary'])
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 106     17         ?  304873        10th              6        Never-married
# 209     17   Private   65368        11th              7        Never-married
# 262     17   Private  245918        11th              7        Never-married
# 271     17   Private  191260         9th              5        Never-married
# 335     17   Private  270942     5th-6th              3        Never-married
# ...    ...       ...     ...         ...            ...                  ...
# 8973    90   Private   46786   Bachelors             13   Married-civ-spouse
# 10545   90   Private  175491     HS-grad              9   Married-civ-spouse
# 15892   90   Private   88991   Bachelors             13   Married-civ-spouse
# 20610   90   Private  206667     Masters             14   Married-civ-spouse
# 31696   90         ?  313986     HS-grad              9   Married-civ-spouse
#
# ...

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
data.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data set gaji.txt')
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
data.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data['workclass'] = \
data['workclass'].map({' State-gov':0, ' Self-emp-not-inc':1, ' Private':2, ' Federal-gov':3, ' Local-gov':4, ' ?':5, ' Self-emp-inc':6, ' Without-pay':7,
                        ' Never-worked':8})
data
# Out:
#        age  workclass  fnlwgt    education  education-num  \
# 0       39          0   77516    Bachelors             13
# 1       50          1   83311    Bachelors             13
# 2       38          2  215646      HS-grad              9
# 3       53          2  234721         11th              7
# 4       28          2  338409    Bachelors             13
# ...    ...        ...     ...          ...            ...
# 32556   27          2  257302   Assoc-acdm             12
# 32557   40          2  154374      HS-grad              9
# 32558   58          2  151910      HS-grad              9
# 32559   22          2  201490      HS-grad              9
# 32560   52          6  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
data['education'] = \
data['education'].map({' Bachelors':0, ' HS-grad':1, ' 11th':2, ' Masters':3, ' 9th':4,
       ' Some-college':5, ' Assoc-acdm':6, ' Assoc-voc':7, ' 7th-8th':8,
       ' Doctorate':9, ' Prof-school':10, ' 5th-6th':11, ' 10th':12, ' 1st-4th':13,
       ' Preschool':14, ' 12th':15})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data['occupation'] = \
data['occupation'].map({' Adm-clerical':0, ' Exec-managerial':1, ' Handlers-cleaners':2,
       ' Prof-specialty':3, ' Other-service':4, ' Sales':5, ' Craft-repair':6,
       ' Transport-moving':7, ' Farming-fishing':8, ' Machine-op-inspct':9,
       ' Tech-support':10, ' ?':11, ' Protective-serv':12, ' Armed-Forces':13,
       ' Priv-house-serv':14})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data.relationship.unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
data['relationship'] = \
data['relationship'].map({' Not-in-family':0, ' Husband':1, ' Wife':2, ' Own-child':3, ' Unmarried':4,
       ' Other-relative':5})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data.race.unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
data['race'] = \
data['race'].map({' White':0, ' Black':1, ' Asian-Pac-Islander':2, ' Amer-Indian-Eskimo':3,
       ' Other':4})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data.sex.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
data['sex'] = \
data['sex'].map({' Male':0, ' Female':1})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data.salary.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data['salary'] = \
data['salary'].map({' <=50K':0, ' >50K':1})
data
# Out:
#        age  workclass  fnlwgt  education  education-num       marital-status  \
# 0       39          0   77516          0             13        Never-married
# 1       50          1   83311          0             13   Married-civ-spouse
# 2       38          2  215646          1              9             Divorced
# 3       53          2  234721          2              7   Married-civ-spouse
# 4       28          2  338409          0             13   Married-civ-spouse
# ...    ...        ...     ...        ...            ...                  ...
# 32556   27          2  257302          6             12   Married-civ-spouse
# 32557   40          2  154374          1              9   Married-civ-spouse
# 32558   58          2  151910          1              9              Widowed
# 32559   22          2  201490          1              9        Never-married
# 32560   52          6  287927          1              9   Married-civ-spouse
#
# ...

# %%
data['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data['marital-status'] = \
data['marital-status'].map({' Never-married':0, ' Married-civ-spouse':1, ' Divorced':2,
       ' Married-spouse-absent':3, ' Separated':4, ' Married-AF-spouse':5,
       ' Widowed':6})
data
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          0   77516          0             13               0
# 1       50          1   83311          0             13               1
# 2       38          2  215646          1              9               2
# 3       53          2  234721          2              7               1
# 4       28          2  338409          0             13               1
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          6             12               1
# 32557   40          2  154374          1              9               1
# 32558   58          2  151910          1              9               6
# 32559   22          2  201490          1              9               0
# 32560   52          6  287927          1              9               1
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
data['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
data['native-country'] = \
data['native-country'].map({' United-States':0, ' Cuba':1, ' Jamaica':2, ' India':3, ' ?':4, ' Mexico':5,
       ' South':6, ' Puerto-Rico':7, ' Honduras':8, ' England':9, ' Canada':10,
       ' Germany':11, ' Iran':12, ' Philippines':13, ' Italy':14, ' Poland':15,
       ' Columbia':16, ' Cambodia':17, ' Thailand':18, ' Ecuador':19, ' Laos':20,
       ' Taiwan':21, ' Haiti':22, ' Portugal':23, ' Dominican-Republic':24,
       ' El-Salvador':25, ' France':26, ' Guatemala':27, ' China':28, ' Japan':29,
       ' Yugoslavia':30, ' Peru':31, ' Outlying-US(Guam-USVI-etc)':32, ' Scotland':33,
       ' Trinadad&Tobago':34, ' Greece':35, ' Nicaragua':36, ' Vietnam':37, ' Hong':38,
       ' Ireland':39, ' Hungary':40, ' Holand-Netherlands':41})
data
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          0   77516          0             13               0
# 1       50          1   83311          0             13               1
# 2       38          2  215646          1              9               2
# 3       53          2  234721          2              7               1
# 4       28          2  338409          0             13               1
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          6             12               1
# 32557   40          2  154374          1              9               1
# 32558   58          2  151910          1              9               6
# 32559   22          2  201490          1              9               0
# 32560   52          6  287927          1              9               1
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
data = pd.get_dummies(data)
data
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          0   77516          0             13               0
# 1       50          1   83311          0             13               1
# 2       38          2  215646          1              9               2
# 3       53          2  234721          2              7               1
# 4       28          2  338409          0             13               1
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          6             12               1
# 32557   40          2  154374          1              9               1
# 32558   58          2  151910          1              9               6
# 32559   22          2  201490          1              9               0
# 32560   52          6  287927          1              9               1
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           0             0     0    0          2174             0
# 1           1             1     0    0             0             0
# 2           2             0     0    0             0             0
# 3           2             1     1    0             0             0
# 4           3             2     1    1             0             0
#
#    hours-per-week  native-country  salary
# 0              40               0       0
# 1              13               0       0
# ...

# %%
data.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000   32561.000000
# mean      38.581647      2.309972  1.897784e+05      3.424465      10.080679
# std       13.640433      1.225728  1.055500e+05      3.453582       2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      2.000000  1.178270e+05      1.000000       9.000000
# 50%       37.000000      2.000000  1.783560e+05      2.000000      10.000000
# 75%       48.000000      2.000000  2.370510e+05      5.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         1.083781      4.666411      1.542397      0.221707      0.330795
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.head(50)
# Out:
#     age  workclass  fnlwgt  education  education-num  marital-status  \
# 0    39          0   77516          0             13               0
# 1    50          1   83311          0             13               1
# 2    38          2  215646          1              9               2
# 3    53          2  234721          2              7               1
# 4    28          2  338409          0             13               1
# 5    37          2  284582          3             14               1
# 6    49          2  160187          4              5               3
# 7    52          1  209642          1              9               1
# 8    31          2   45781          3             14               0
# 9    42          2  159449          0             13               1
# 10   37          2  280464          5             10               1
# 11   30          0  141297          0             13               1
# 12   23          2  122272          0             13               0
# ...

# %%
X = data.drop(['salary'],axis=1)
y = data['salary']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn import svm
model_svm = svm.SVC()

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
model_svm.score(X_test,y_test)
# Out:
# 0.798710271764164

# %%
data.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000   32561.000000
# mean      38.581647      2.309972  1.897784e+05      3.424465      10.080679
# std       13.640433      1.225728  1.055500e+05      3.453582       2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      2.000000  1.178270e+05      1.000000       9.000000
# 50%       37.000000      2.000000  1.783560e+05      2.000000      10.000000
# 75%       48.000000      2.000000  2.370510e+05      5.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         1.083781      4.666411      1.542397      0.221707      0.330795
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.relplot(x='age', y='salary', data=data)
plt.show()

# %%
import seaborn as sns
sns.countplot(y=data["relationship"], hue=data["relationship"])
plt.show()
sns.countplot(y=data["education-num"], hue=data["education-num"])
plt.show()
sns.countplot(y=data["occupation"], hue=data["occupation"])
plt.show()

# %%
import numpy as np
from scipy import stats

mean = np.mean(data['salary'])
median = np.median(data['salary'])
mode = stats.mode(data['salary'])

print('Rata-rata: ', mean)
print('Median: ', median)
print('Modus: ', mode)
# Out:
# Rata-rata:  0.2408095574460244
# Median:  0.0
# Modus:  ModeResult(mode=array([0]), count=array([24720]))
# <ipython-input-46-b28b09f84450>:6: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(data['salary'])
